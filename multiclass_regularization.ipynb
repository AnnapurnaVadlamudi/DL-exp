# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnapurnaVadlamudi/DL-exp/blob/main/multiclass_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 122ms/step - loss: 7.1796 - categorical_accuracy: 0.4351 - val_loss: 3.7452 - val_categorical_accuracy: 0.5462
# Epoch 2/25
# 16/16 [==============================] - 1s 61ms/step - loss: 3.4161 - categorical_accuracy: 0.5561 - val_loss: 3.1332 - val_categorical_accuracy: 0.6000
# Epoch 3/25
# 16/16 [==============================] - 1s 54ms/step - loss: 3.0450 - categorical_accuracy: 0.6167 - val_loss: 2.8955 - val_categorical_accuracy: 0.6463
# Epoch 4/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.8449 - categorical_accuracy: 0.6461 - val_loss: 2.7118 - val_categorical_accuracy: 0.6600
# Epoch 5/25
# 16/16 [==============================] - 1s 49ms/step - loss: 2.7045 - categorical_accuracy: 0.6596 - val_loss: 2.5975 - val_categorical_accuracy: 0.6762
# Epoch 6/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.5830 - categorical_accuracy: 0.6760 - val_loss: 2.4912 - val_categorical_accuracy: 0.6762
# Epoch 7/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.4920 - categorical_accuracy: 0.6781 - val_loss: 2.4413 - val_categorical_accuracy: 0.6787
# Epoch 8/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.4044 - categorical_accuracy: 0.6857 - val_loss: 2.3457 - val_categorical_accuracy: 0.6900
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.3389 - categorical_accuracy: 0.6858 - val_loss: 2.2735 - val_categorical_accuracy: 0.6900
# Epoch 10/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.2752 - categorical_accuracy: 0.6931 - val_loss: 2.2199 - val_categorical_accuracy: 0.6925
# Epoch 11/25
# 16/16 [==============================] - 1s 75ms/step - loss: 2.2347 - categorical_accuracy: 0.6896 - val_loss: 2.1744 - val_categorical_accuracy: 0.6963
# Epoch 12/25
# 16/16 [==============================] - 2s 97ms/step - loss: 2.1919 - categorical_accuracy: 0.6934 - val_loss: 2.1766 - val_categorical_accuracy: 0.6975
# Epoch 13/25
# 16/16 [==============================] - 1s 71ms/step - loss: 2.1543 - categorical_accuracy: 0.6954 - val_loss: 2.1185 - val_categorical_accuracy: 0.6950
# Epoch 14/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.1265 - categorical_accuracy: 0.6940 - val_loss: 2.1188 - val_categorical_accuracy: 0.6988
# Epoch 15/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.1042 - categorical_accuracy: 0.6978 - val_loss: 2.0594 - val_categorical_accuracy: 0.6988
# Epoch 16/25
# 16/16 [==============================] - 1s 49ms/step - loss: 2.0760 - categorical_accuracy: 0.6989 - val_loss: 2.0560 - val_categorical_accuracy: 0.7000
# Epoch 17/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0582 - categorical_accuracy: 0.6982 - val_loss: 2.0325 - val_categorical_accuracy: 0.7025
# Epoch 18/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.0392 - categorical_accuracy: 0.6976 - val_loss: 2.0154 - val_categorical_accuracy: 0.7025
# Epoch 19/25
# 16/16 [==============================] - 1s 49ms/step - loss: 2.0211 - categorical_accuracy: 0.6987 - val_loss: 1.9963 - val_categorical_accuracy: 0.7025
# Epoch 20/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0053 - categorical_accuracy: 0.6987 - val_loss: 1.9823 - val_categorical_accuracy: 0.6988
# Epoch 21/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9980 - categorical_accuracy: 0.6981 - val_loss: 1.9681 - val_categorical_accuracy: 0.7038
# Epoch 22/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9788 - categorical_accuracy: 0.6991 - val_loss: 1.9561 - val_categorical_accuracy: 0.7063
# Epoch 23/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9707 - categorical_accuracy: 0.7009 - val_loss: 1.9583 - val_categorical_accuracy: 0.6963
# Epoch 24/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9546 - categorical_accuracy: 0.7015 - val_loss: 1.9455 - val_categorical_accuracy: 0.7038
# Epoch 25/25
# 16/16 [==============================] - 1s 56ms/step - loss: 1.9454 - categorical_accuracy: 0.7025 - val_loss: 1.9458 - val_categorical_accuracy: 0.7025

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
