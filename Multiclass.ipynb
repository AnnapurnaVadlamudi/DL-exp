# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnapurnaVadlamudi/DL-exp/blob/main/Multiclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 65ms/step - loss: 0.1280 - categorical_accuracy: 0.9554 - val_loss: 0.9818 - val_categorical_accuracy: 0.8112
# Epoch 2/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1148 - categorical_accuracy: 0.9545 - val_loss: 0.9932 - val_categorical_accuracy: 0.8138
# Epoch 3/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1072 - categorical_accuracy: 0.9583 - val_loss: 1.0460 - val_categorical_accuracy: 0.8062
# Epoch 4/25
# 16/16 [==============================] - 1s 68ms/step - loss: 0.1068 - categorical_accuracy: 0.9583 - val_loss: 0.9876 - val_categorical_accuracy: 0.8138
# Epoch 5/25
# 16/16 [==============================] - 1s 84ms/step - loss: 0.1043 - categorical_accuracy: 0.9569 - val_loss: 0.9893 - val_categorical_accuracy: 0.8163
# Epoch 6/25
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1102 - categorical_accuracy: 0.9578 - val_loss: 0.9776 - val_categorical_accuracy: 0.8125
# Epoch 7/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1003 - categorical_accuracy: 0.9588 - val_loss: 1.0275 - val_categorical_accuracy: 0.8100
# Epoch 8/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1020 - categorical_accuracy: 0.9591 - val_loss: 0.9962 - val_categorical_accuracy: 0.8188
# Epoch 9/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1039 - categorical_accuracy: 0.9593 - val_loss: 0.9869 - val_categorical_accuracy: 0.8163
# Epoch 10/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0972 - categorical_accuracy: 0.9580 - val_loss: 1.0251 - val_categorical_accuracy: 0.8025
# Epoch 11/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1059 - categorical_accuracy: 0.9586 - val_loss: 1.0369 - val_categorical_accuracy: 0.8138
# Epoch 12/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1006 - categorical_accuracy: 0.9582 - val_loss: 1.0275 - val_categorical_accuracy: 0.8037
# Epoch 13/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0985 - categorical_accuracy: 0.9581 - val_loss: 1.0158 - val_categorical_accuracy: 0.8163
# Epoch 14/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0986 - categorical_accuracy: 0.9578 - val_loss: 1.0641 - val_categorical_accuracy: 0.8075
# Epoch 15/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1000 - categorical_accuracy: 0.9562 - val_loss: 1.0262 - val_categorical_accuracy: 0.8125
# Epoch 16/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0971 - categorical_accuracy: 0.9603 - val_loss: 1.0446 - val_categorical_accuracy: 0.8012
# Epoch 17/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0966 - categorical_accuracy: 0.9584 - val_loss: 1.0312 - val_categorical_accuracy: 0.8062
# Epoch 18/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0963 - categorical_accuracy: 0.9571 - val_loss: 1.0539 - val_categorical_accuracy: 0.8075
# Epoch 19/25
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0964 - categorical_accuracy: 0.9570 - val_loss: 1.0500 - val_categorical_accuracy: 0.8112
# Epoch 20/25
# 16/16 [==============================] - 1s 81ms/step - loss: 0.0983 - categorical_accuracy: 0.9571 - val_loss: 1.0221 - val_categorical_accuracy: 0.8150
# Epoch 21/25
# 16/16 [==============================] - 1s 82ms/step - loss: 0.0965 - categorical_accuracy: 0.9587 - val_loss: 1.0426 - val_categorical_accuracy: 0.8112
# Epoch 22/25
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0928 - categorical_accuracy: 0.9587 - val_loss: 1.0543 - val_categorical_accuracy: 0.8012
# Epoch 23/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0965 - categorical_accuracy: 0.9572 - val_loss: 1.0376 - val_categorical_accuracy: 0.8138
# Epoch 24/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0970 - categorical_accuracy: 0.9584 - val_loss: 1.1045 - val_categorical_accuracy: 0.7950
# Epoch 25/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0918 - categorical_accuracy: 0.9586 - val_loss: 1.0208 - val_categorical_accuracy: 0.8188

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
